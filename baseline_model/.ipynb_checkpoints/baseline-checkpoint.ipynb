# %% [markdown]
# # Used Modules
# ## TUM69.jl
# It is used as a loader module of the data. It walks around the all material folders and fetches them as a data array or image.
#
# ## Preprocess.jl
# It contains the necessary preprocessing operations that should be exerted on the acceleration signals or camera images.
#
# ## Network.jl
# It contains the necessary definitions for the custom network model that will be built for the study.
#
# ## Utils.jl
# It includes the necessary and auxiliary functionalities that might be probably used troughout the project.

# %%
include("../src/modules/TUM69.jl")
include("../src/modules/Preprocess.jl")
include("../src/modules/Network.jl")
include("../src/modules/Utils.jl")

## Third party packages
using PyPlot: plot, specgram, subplot, xlabel, ylabel, title, legend
using Images
using ImageView: imshow
using Knet: minibatch

## Handwritten modules
using .TUM69: loaddata   # Data reading
using .Preprocess: process_accel_signal, process_image # Preprocessing on the data
using .Network: Conv, Dense, VisualNet, train!, accuracy # Construction of custom network
using .Utils: plot_spectrogram

# %%
data_path = "./../data/new"
# Out:
# "./../data/new"

# %% [markdown]
# # loaddata()
# + The main function handle that reads the whole data.
# + The mode = "baseline" option is applicable only for this baseline representation.
# + This option allows us to read only 1 data file from each material folder.
# + Since my memory is very limited, I figured it would be a good idea to do in this way.

# %%
X_accel_train, y_accel_train,
X_accel_test, y_accel_test, 
X_image_train, y_image_train, 
X_image_test,y_image_test,
material_dict = loaddata(data_path; mode = "baseline" );
# Out:
# Train accel data is being loaded!
# Train image data is being loaded!
# Test accel data is being loaded!
# Test image data is being loaded!

# %% [markdown]
# # Summary of the Data

# %%
println("X_accel_train = ", summary(X_accel_train))
println("y_accel_train = ", summary(y_accel_train))
println("X_accel_test  = ", summary(X_accel_test))
println("y_accel_test  = ", summary(y_accel_test))
println("X_image_train = ", summary(X_image_train))
println("y_image_train = ", summary(y_image_train))
println("X_image_test  = ", summary(X_image_test))
println("y_image_test  = ", summary(y_image_test))
println("material_dict = ", summary(material_dict))
# Out:
# X_accel_train = 69-element Array{Array{Float32,1},1}
# y_accel_train = 69-element Array{Int8,1}
# X_accel_test  = 69-element Array{Array{Float32,1},1}
# y_accel_test  = 69-element Array{Int8,1}
# X_image_train = 69-element Array{Array{RGB{Normed{UInt8,8}},2},1}
# y_image_train = 69-element Array{Int8,1}
# X_image_test  = 69-element Array{Array{RGB{Normed{UInt8,8}},2},1}
# y_image_test  = 69-element Array{Int8,1}
# material_dict = Dict{String,Int8} with 69 entries

# %% [markdown]
# # Examples from the Data

# %% [markdown]
# ## Example Acceleration Data

# %%
for k in 1:3
subplot(3,1,k)
plot(X_accel_train[k])
end
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 3 Axes>)

# %% [markdown]
# ## Example Camera Images

# %%
X_image_train[1]
# Out:
# 3264×2448 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(0.733,0.655,0.408)  …  RGB{N0f8}(0.863,0.824,0.541)
#  RGB{N0f8}(0.737,0.659,0.412)     RGB{N0f8}(0.851,0.812,0.529)
#  RGB{N0f8}(0.765,0.678,0.443)     RGB{N0f8}(0.835,0.804,0.518)
#  RGB{N0f8}(0.737,0.651,0.416)     RGB{N0f8}(0.835,0.804,0.518)
#  RGB{N0f8}(0.714,0.627,0.4)       RGB{N0f8}(0.839,0.812,0.529)
#  RGB{N0f8}(0.737,0.651,0.424)  …  RGB{N0f8}(0.855,0.827,0.545)
#  RGB{N0f8}(0.745,0.659,0.435)     RGB{N0f8}(0.863,0.835,0.553)
#  RGB{N0f8}(0.753,0.667,0.443)     RGB{N0f8}(0.863,0.835,0.553)
#  RGB{N0f8}(0.776,0.686,0.475)     RGB{N0f8}(0.875,0.839,0.576)
#  RGB{N0f8}(0.761,0.671,0.459)     RGB{N0f8}(0.875,0.839,0.576)
#  RGB{N0f8}(0.741,0.651,0.439)  …  RGB{N0f8}(0.886,0.831,0.592)
#  RGB{N0f8}(0.725,0.635,0.424)     RGB{N0f8}(0.89,0.835,0.596)
#  RGB{N0f8}(0.718,0.635,0.412)     RGB{N0f8}(0.906,0.831,0.604)
#  ⋮                             ⋱
# ...

# %%
X_image_train[2]
# Out:
# 3264×2448 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(0.525,0.482,0.475)  …  RGB{N0f8}(0.655,0.616,0.518)
#  RGB{N0f8}(0.525,0.482,0.475)     RGB{N0f8}(0.675,0.635,0.537)
#  RGB{N0f8}(0.537,0.482,0.478)     RGB{N0f8}(0.698,0.659,0.561)
#  RGB{N0f8}(0.525,0.471,0.467)     RGB{N0f8}(0.706,0.667,0.569)
#  RGB{N0f8}(0.529,0.475,0.463)     RGB{N0f8}(0.706,0.667,0.569)
#  RGB{N0f8}(0.561,0.506,0.494)  …  RGB{N0f8}(0.706,0.667,0.569)
#  RGB{N0f8}(0.525,0.475,0.451)     RGB{N0f8}(0.718,0.675,0.588)
#  RGB{N0f8}(0.427,0.376,0.353)     RGB{N0f8}(0.729,0.686,0.6)
#  RGB{N0f8}(0.514,0.463,0.439)     RGB{N0f8}(0.71,0.663,0.576)
#  RGB{N0f8}(0.537,0.486,0.463)     RGB{N0f8}(0.706,0.659,0.573)
#  RGB{N0f8}(0.514,0.471,0.447)  …  RGB{N0f8}(0.71,0.659,0.584)
#  RGB{N0f8}(0.498,0.455,0.431)     RGB{N0f8}(0.718,0.667,0.592)
#  RGB{N0f8}(0.31,0.275,0.247)      RGB{N0f8}(0.718,0.667,0.592)
#  ⋮                             ⋱
# ...

# %%
X_image_train[3]
# Out:
# 3264×2448 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(0.851,0.816,0.78)   …  RGB{N0f8}(0.886,0.867,0.753)
#  RGB{N0f8}(0.816,0.78,0.745)      RGB{N0f8}(0.878,0.855,0.761)
#  RGB{N0f8}(0.78,0.749,0.706)      RGB{N0f8}(0.871,0.843,0.78)
#  RGB{N0f8}(0.8,0.769,0.725)       RGB{N0f8}(0.871,0.839,0.788)
#  RGB{N0f8}(0.824,0.792,0.749)     RGB{N0f8}(0.867,0.843,0.788)
#  RGB{N0f8}(0.82,0.788,0.745)   …  RGB{N0f8}(0.871,0.847,0.784)
#  RGB{N0f8}(0.816,0.784,0.741)     RGB{N0f8}(0.871,0.847,0.792)
#  RGB{N0f8}(0.8,0.769,0.725)       RGB{N0f8}(0.867,0.843,0.788)
#  RGB{N0f8}(0.82,0.788,0.737)      RGB{N0f8}(0.867,0.843,0.788)
#  RGB{N0f8}(0.808,0.776,0.725)     RGB{N0f8}(0.863,0.839,0.776)
#  RGB{N0f8}(0.82,0.796,0.741)   …  RGB{N0f8}(0.863,0.835,0.761)
#  RGB{N0f8}(0.82,0.796,0.741)      RGB{N0f8}(0.871,0.843,0.769)
#  RGB{N0f8}(0.804,0.78,0.733)      RGB{N0f8}(0.878,0.851,0.78)
#  ⋮                             ⋱
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Acceleration Data Preprocessing

# %% [markdown]
# For the acceleration data:
# + The spectrogram of each acceleration signal is constructed
# + First 50 frequencies is fetched, since they include most of the power of the signal

# %% [markdown]
# ### Example Spectrogram of Acceleration Signal

# %%
plot_spectrogram(X_accel_train[1], 10000);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plot_spectrogram(X_accel_train[2], 10000);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plot_spectrogram(X_accel_train[3], 10000);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Basically, our new input data will be the below yellowish region of the spectrogram rather than time series acceleration signal

# %%
X_accel_train = process_accel_signal.(X_accel_train);
X_accel_test = process_accel_signal.(X_accel_test);

# %% [markdown]
# ## Image Data Preprocessing

# %% [markdown]
# *All I have done is to resize to image with a scale factor of $0.1$*
# * Scale factor is small due to the fact that it is only a baseline model!

# %%
X_image_train = process_image.(X_image_train);
X_image_test = process_image.(X_image_test);

# %% [markdown]
# **Finally, all the data should be concetenated to be able to represent whole instances.**

# %%
X_image_train = cat(X_image_train..., dims = 4); y_image_train .+= 1;
X_image_test = cat(X_image_test..., dims = 4); y_image_test .+= 1;
X_accel_train = cat(X_accel_train..., dims = 4);
X_accel_test = cat(X_accel_test..., dims = 4);

# %%
println("X_accel_train = ", summary(X_accel_train))
println("y_accel_train = ", summary(y_accel_train))
println("X_accel_test  = ", summary(X_accel_test))
println("y_accel_test  = ", summary(y_accel_test))
println("X_image_train = ", summary(X_image_train))
println("y_image_train = ", summary(y_image_train))
println("X_image_test  = ", summary(X_image_test))
println("y_image_test  = ", summary(y_image_test))
println("material_dict = ", summary(material_dict))
# Out:
# X_accel_train = 50×1000×1×69 Array{Float32,4}
# y_accel_train = 69-element Array{Int8,1}
# X_accel_test  = 50×1000×1×69 Array{Float32,4}
# y_accel_test  = 69-element Array{Int8,1}
# X_image_train = 327×245×3×69 Array{Float32,4}
# y_image_train = 69-element Array{Int8,1}
# X_image_test  = 327×245×3×69 Array{Float32,4}
# y_image_test  = 69-element Array{Int8,1}
# material_dict = Dict{String,Int8} with 69 entries

# %% [markdown]
# # Neural Network Model

# %% [markdown]
# ## Convolutional Neural Network for Texture Image Recognition

# %% [markdown]
# In this baseline model, the similar architecture that the authors used is constructed.

# %%
VNet =VisualNet(Conv(5,5,3,20), 
                Conv(5,5,20,50),
                Conv(5,5,50,100),
                Conv(5,5,100,200),
                Conv(5,5,200,400),
                Dense(7200,500,pdrop=0.3), 
                Dense(500,69,identity,pdrop=0.3))
summary.(l.w for l in VNet.layers)
# Out:
# 7-element Array{String,1}:
#  "5×5×3×20 AutoGrad.Param{Array{Float32,4}}"
#  "5×5×20×50 AutoGrad.Param{Array{Float32,4}}"
#  "5×5×50×100 AutoGrad.Param{Array{Float32,4}}"
#  "5×5×100×200 AutoGrad.Param{Array{Float32,4}}"
#  "5×5×200×400 AutoGrad.Param{Array{Float32,4}}"
#  "500×7200 AutoGrad.Param{Array{Float32,2}}"
#  "69×500 AutoGrad.Param{Array{Float32,2}}"

# %% [markdown]
# However, since the amount of the data is really small in the baseline, it is not possible to obtain reasonable outcomes.

# %%
dtrn = minibatch(X_image_train, y_image_train, 10)
dtst = minibatch(X_image_test, y_image_test, 10)
# Out:
# 6-element Knet.Train20.Data{Tuple{Array{Float32,N} where N,Array{Int8,N} where N}}

# %%
iters, train_loss, test_loss = train!(VNet, dtrn, dtst; period = 10, iters = 100)
# Out:
# ┣████████████████████┫ [100.00%, 10/10, 00:49/00:49, 4.88s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:38/00:38, 3.83s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:37/00:37, 3.70s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:36/00:36, 3.55s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:35/00:35, 3.52s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:30/00:30, 2.98s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:35/00:35, 3.53s/i] ██                ┫ [20.00%, 2/10, 00:07/00:35, 4.29s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:34/00:34, 3.38s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:30/00:30, 3.01s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:30/00:30, 2.98s/i]
# ┣████████████████████┫ [100.00%, 10/10, 00:34/00:34, 3.36s/i]
# ...

# %% [markdown]
# ## Plot of the Result

# %%
plot(iters, train_loss, label = "Train Loss")
plot(iters, test_loss, label = "Test Loss")
xlabel("Epochs")
ylabel("Loss")
legend(loc = "best")
title("First Run Results")
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1.0, 'First Run Results')

# %% [markdown]
# ## Accuracy Metric

# %%
accuracy(VNet, dtst)
# Out:
# 0.016666666666666666

# %% [markdown]
# * Note that the loss value at the beginning of the iteration is $4.23 = ln(69)$
# * 69 is the number of classes in the model.

# %% [markdown]
# Also, it was observed that the loss is not tended to decrease in this model. It is probably due to the small number of instances vs. huge number of parameter space. The model cannot learn anything in that much low iteration.

# %% [markdown]
# # Future Work

# %% [markdown]
# * Acceleration signals will be divided into chunks. It can be observed from above acceleration signal time-series plots that the signal consists of a lot of repetitive parts. Therefore, in future model, these repetitive parts will be trained, and the *loss* of the model will be calculated via using **Max-Voting Scheme**

# %% [markdown]
# * Moreover, the similar procedure will be applied on the camera images. Again, the texture images are nothing but the constitution of repetitive pattern along 2D plane. Therefore, the training via chunking and loss calculation via Max-Voting Scheme can be applicable.

# %% [markdown]
# * Finally, to boost the performance, the pretrained ImageNet layers will be added to the model so as to make use of the previously learned image recognition model.
